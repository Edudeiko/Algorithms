# %%
animals = ['Duck', 'Jackal', 'Hippo', 'Aardvark', 'Cat', 'Flamingo', 'Iguana', 'Giraffe',
           'Elephant', 'Bear', 'Cat', 'Dog', 'Goose', 'Antilope']
# Print all the animals

# How much longer is this going
# to take to run as the size of the data set

# Increases?
#
# If we double it, twice as long
# Halve it, half as long
# triple it, three times as long

# Linear time, O(n)

def print_animals():
    for a in animals:  # O(n) over the number of animals
        print(a)       # dependent on the number of animals
        
def print_animal(i):  # O(1) over the number of animals
    print(animals[i])
    
def print_animal_2(i):  # O(1) over the number of animals
    for c in animals[i]:      # O(n) over the length of the string
        print(c)        # doesn't matter how many names (1 or 4 Bil) only matters the length of the animals name

# 2 and 3 similar on how they scale

# 1. Wrote down the big O of each line in isolation
# * Loops get O(n)
# * Most other single lines get O(1)
# 2. Add the big O of things in series
# 3. Multiply the big O of each loop by its body

def find_dups():
    for i0 in range(len(animals)):  # n (over the number of animals)
        for i1 in range(len(animals)):  # n (over the number of animals)
            if i0 == i1:                # 1 constant time
                continue                # 1 
                
            if animals[i0] == animals[i1]:  # 1
                print(f'Duplicates: {animals[i0]}')  # 1
                
def print_animals_3():
    
#     O(n + n) == O(2n) == O(n)
    for a in animals:
        print(a)
        
    for a in animals:
        print(a)

# for i in range(10000000000000000000000000):  # O(1)
#     print(animals[0])  # O(1)

# same amount of time to run
    
for i in range(10):  # O(1)
    print(animals[0])  # O(1)

def print_animal_triples():
    for animal_1 in animals:
        for animal_2 in animals:
            for animal_3 in animals:
                print(f'{animal_1} - {animal_2} - {animal_3}')
                
    """
    Better than O(n)
        O(log n)
        O(1)

    Worse, but not bad:
        O(n log n)

    Bad:
        O(n^2)
        O(n^3)
        O(2^n)
        O(n!)
    """
# Out:
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck
# Duck

# %%
print_animal_2(3)
# Out:
# A
# a
# r
# d
# v
# a
# r
# k

# %%
print_animal(2)
# Out:
# Hippo

# %%
find_dups()
# Out:
# Duplicates: Cat
# Duplicates: Cat

# %%
print_animal_triples()
# Out:
# Duck - Duck - Duck
# Duck - Duck - Jackal
# Duck - Duck - Hippo
# Duck - Duck - Aardvark
# Duck - Duck - Cat
# Duck - Duck - Flamingo
# Duck - Duck - Iguana
# Duck - Duck - Giraffe
# Duck - Duck - Elephant
# Duck - Duck - Bear
# Duck - Duck - Cat
# Duck - Duck - Dog
# Duck - Duck - Goose
# Duck - Duck - Antilope
# Duck - Jackal - Duck
# Duck - Jackal - Jackal
# Duck - Jackal - Hippo
# Duck - Jackal - Aardvark
# Duck - Jackal - Cat
# Duck - Jackal - Flamingo
# Duck - Jackal - Iguana
# Duck - Jackal - Giraffe
# Duck - Jackal - Elephant
# Duck - Jackal - Bear
# Duck - Jackal - Cat
# Duck - Jackal - Dog
# Duck - Jackal - Goose
# Duck - Jackal - Antilope
# Duck - Hippo - Duck
# Duck - Hippo - Jackal
# Duck - Hippo - Hippo
# Duck - Hippo - Aardvark
# Duck - Hippo - Cat
# Duck - Hippo - Flamingo
# Duck - Hippo - Iguana
# Duck - Hippo - Giraffe
# Duck - Hippo - Elephant
# Duck - Hippo - Bear
# Duck - Hippo - Cat
# Duck - Hippo - Dog
# Duck - Hippo - Goose
# Duck - Hippo - Antilope
# ...

# %%
# O(n log n + log n) What is the dominant term?
# it all's became a -> O(n log n)
animals = ['Duck', 'Jackal', 'Hippo', 'Aardvark', 'Cat', 'Flamingo', 'Iguana', 'Giraffe',
           'Elephant', 'Bear', 'Cat', 'Dog', 'Goose', 'Antilope']

animals.sort()  # O(n log n)
print(animals)

"""
['Aardvark', 'Antilope', 'Bear', 'Cat', 'Cat', 'Dog', 'Duck', 'Elephant', 'Flamingo', 'Giraffe', 'Goose', 'Hippo', 'Iguana', 'Jackal']
['Aardvark', 'Antilope', 'Bear', 'Cat', 'Cat', 'Dog', 'Duck']
['Aardvark', 'Antilope', 'Bear']
['Bear']
"""

def binary_search(a):
    pass

print(binary_search('Fish'))

# Linear search, O(n) over number of animals
def find_animal(a):
    for animal in animals:  # O(n) over number of animals
        if animal == a:
            return True
        
    return False

print(find_animal('Goose'))
print(find_animal('Rockfish'))
# Out:
# ['Aardvark', 'Antilope', 'Bear', 'Cat', 'Cat', 'Dog', 'Duck', 'Elephant', 'Flamingo', 'Giraffe', 'Goose', 'Hippo', 'Iguana', 'Jackal']
# None
# True
# False

# %%
           _
my_list = [8, 2, 5, 4, 1, 3]
           __________
my_list = [2, 4, 5, 8, 1, 3]

# %%
my_list = [8, 2, 5, 4, 1, 3]
# my_list = [2, 1, 3]

def insertion_sort_not_in_place(unsorted_list):  # Not 'in-place'
    sorted_list = []
    
    for n in unsorted_list:
        index = 0

        for i in range(len(sorted_list) -1, -1, -1):
#             print(f'{i}, {n}')
            if sorted_list[i] < n:
                index = i + 1
                break
                
        sorted_list.insert(index, n)
#         print('inserting at', index)
#         print(sorted_list)
        
    return sorted_list
                
#             if index is not None:
#                 insert it there
#             else:
def insertion_sort(a):
    for i in range(1, len(a)):
        val = a[i]
        
        j = i
        
        while j > 0 and val < a[j - 1]:
            a[j], a[j-1] = a[j-1], a[j]  # swap a,b = a,b
            j -= 1
            
            
    
sorted_list = insertion_sort_not_in_place(my_list)
print(f'sorted 1:', sorted_list)

insertion_sort(my_list)
print(f'sorted 2:', my_list)
# Out:
# sorted 1: [1, 2, 3, 4, 5, 8]
# sorted 2: [1, 2, 3, 4, 5, 8]
